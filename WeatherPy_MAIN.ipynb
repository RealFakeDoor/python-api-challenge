# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
print(weather_api_key)
# Out:
# a4d6d40801f3e0763db674b53a47d6ac

# %%
# Empty list for holding the latitude and longitude combinations.
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %%
print(cities)
# Out:
# ['abepura', 'katsuren-haebaru', 'utrik', 'wailua homesteads', 'grytviken', 'longyearbyen', 'west island', 'lisala', 'waitangi', 'ta`u', 'sandnessjoen', 'guerrero negro', 'yellowknife', 'porto novo', 'edinburgh of the seven seas', 'orcopampa', 'tiksi', 'san antonio de pale', 'markovo', 'port mathurin', 'adamstown', 'hermanus', 'isafjordur', 'iqaluit', 'chonchi', 'cascais', 'chos malal', 'ribeira grande', 'saipan', 'bikenibeu village', 'stanley', 'khabary', 'taulaga', 'hamilton', 'shelton', 'scottburgh', 'vingt cinq', 'reggane', 'puerto natales', "arkhangel'sk", 'vernon', 'hasaki', 'jamestown', 'lebu', 'kununurra', 'bardai', 'karratha', 'alofi', 'hawaiian paradise park', 'arraial do cabo', 'sonqor', 'minas de marcona', 'east london', 'sergeyevka', 'cadale', 'aral', 'balakovo', 'bridgewater', 'blackmans bay', 'bethel', 'port-aux-francais', 'saint-philippe', 'broome', 'pak phanang', 'djougou', 'sidney', 'sihanoukville', 'dudinka', 'yanta', 'carnarvon', 'tanki leendert', 'eureka', 'labrador city', 'margaret river', "'ohonua", 'lagoa', 'kruisfontein', 'cabo san lucas', 'puerto san carlos', 'ushuaia', 'kikwit', 'murgab', 'the pas', 'at taj', 'kuraymah', 'hotan', 'papatowai', 'la ronge', 'calama', 'codrington', 'pisco', 'fale old settlement', 'ust-nera', 'avarua', 'touros', 'whitehorse', "al 'alamayn", 'oroqen zizhiqi', 'ilulissat', 'nishinoomote', 'sao paulo de olivenca', 'dembi dolo', 'walvis bay', 'higuera de zaragoza', 'xilin hot', 'lihue', 'tsiombe', 'san jose del guaviare', 'nova sintra', 'keflavik', 'pathein', 'kataragama', 'cable beach', 'westport', 'talnakh', 'kilindoni', 'kyzyl-suu', 'bodo', 'aasiaat', 'college', 'vila franca do campo', 'bilibino', 'kirakira', 'mejit', 'san patricio', "st. john's", 'murray', 'albany', 'bredasdorp', 'tura', 'qapqal', 'cape coast', 'tvoroyri', 'trenggalek', 'nueva gerona', 'neiafu', 'olonkinbyen', 'gurlan', 'kodiak', 'anadyr', 'kapuskasing', 'goure', "nuku'alofa", 'afaahiti', 'invercargill', 'ancud', 'kyabe', 'thompson', 'atafu village', 'mirriah', 'constantia', "la'ie", 'mansa', 'taiohae', 'langfang', 'port alfred', 'lompoc', "hayma'", 'dunedin', 'tual', 'kavaratti', 'dongtai', 'prum', 'pangody', 'mount isa', "kapa'a", 'udachny', 'georgetown', 'tommot', 'teknaf', 'saldanha', 'qaqortoq', 'kalispell', 'ugoofaaru', 'spittal an der drau', 'conception bay south', 'acapulco de juarez', 'luderitz', 'kerema', 'gamay', 'petropavlovsk-kamchatsky', 'villa alberto andres alvarado aramburo', 'weno', 'hirara', 'kokopo', 'columbia falls', 'rongelap', 'cromwell', 'san jose village', 'sanya', 'oeiras do para', 'shimoda', 'alice springs', 'puerto ayora', 'concepcion', 'kzyltu', 'fujin', 'necochea', 'gumdag', 'inhambane', 'cidade velha', 'alesund', 'brejo', 'progreso', 'itirucu', 'puli', 'sitka', 'roxas city', 'pauini', 'furmanov', 'klyuchi', 'amos', 'hadibu', 'revda', 'monte patria', 'islamorada', 'novouzensk', 'fandrandava', 'susuman', 'las heras', 'okhotsk', 'ambon', 'murghob', 'port lincoln', 'vorgashor', 'sirte', 'mossel bay', 'marsh harbour', 'dame-marie', 'ujae', 'tromso', 'umba', 'pueblo nuevo', 'papao', 'ruayer', 'la romana', 'bandarbeyla', 'belyy yar', 'hinton', 'antalaha', 'midvagur', 'iskateley', 'cole harbour', 'ulladulla', 'mount gambier', 'nguruka', 'tanumah', 'portland', 'port elizabeth', 'angaur state', 'jatai', 'colonia', 'palamos', 'sinabang', 'kingston', 'tranovaho', "port saint john's", 'mar del plata', 'badger', 'harstad', 'homer', 'tomatlan', 'tralee', 'crane', 'vilyuysk', 'taksimo', 'mount pleasant', 'betio village', 'ponneri', 'rawson', 'zouerate', 'nacozari de garcia', 'port douglas', 'khovd', 'turabah', 'kazalinsk', 'uliastay', 'la paz', 'ipora', 'woodlake', 'pointe michel', 'enewetak', 'nagqu', 'vadso', 'franceville', 'brigantine', 'devinuwara', 'khorixas', 'lembar', 'eldorado', 'faya-largeau', 'nafada', 'cifuentes', 'uturoa', 'puerto baquerizo moreno', 'praia', 'hailar', 'chicoral', 'malanje', 'linxia chengguanzhen', 'trenton', 'minas', 'rio de janeiro', 'mournies', 'kani keli', 're ...

# %%
# Set the API base URL                                                        https://api.openweathermap.org/data/2.5/weather?
url = f'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country =city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | abepura
# Processing Record 2 of Set 1 | katsuren-haebaru
# Processing Record 3 of Set 1 | utrik
# Processing Record 4 of Set 1 | wailua homesteads
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | west island
# Processing Record 8 of Set 1 | lisala
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | ta`u
# Processing Record 11 of Set 1 | sandnessjoen
# Processing Record 12 of Set 1 | guerrero negro
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | porto novo
# Processing Record 15 of Set 1 | edinburgh of the seven seas
# Processing Record 16 of Set 1 | orcopampa
# Processing Record 17 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 18 of Set 1 | san antonio de pale
# Processing Record 19 of Set 1 | markovo
# Processing Record 20 of Set 1 | port mathurin
# Processing Record 21 of Set 1 | adamstown
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | isafjordur
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | chonchi
# Processing Record 26 of Set 1 | cascais
# Processing Record 27 of Set 1 | chos malal
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | saipan
# Processing Record 30 of Set 1 | bikenibeu village
# Processing Record 31 of Set 1 | stanley
# Processing Record 32 of Set 1 | khabary
# Processing Record 33 of Set 1 | taulaga
# Processing Record 34 of Set 1 | hamilton
# Processing Record 35 of Set 1 | shelton
# Processing Record 36 of Set 1 | scottburgh
# Processing Record 37 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 38 of Set 1 | reggane
# Processing Record 39 of Set 1 | puerto natales
# Processing Record 40 of Set 1 | arkhangel'sk
# Processing Record 41 of Set 1 | vernon
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | kununurra
# Processing Record 46 of Set 1 | bardai
# Processing Record 47 of Set 1 | karratha
# Processing Record 48 of Set 1 | alofi
# Processing Record 49 of Set 1 | hawaiian paradise park
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 0 of Set 2 | sonqor
# Processing Record 1 of Set 2 | minas de marcona
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | sergeyevka
# Processing Record 4 of Set 2 | cadale
# Processing Record 5 of Set 2 | aral
# Processing Record 6 of Set 2 | balakovo
# Processing Record 7 of Set 2 | bridgewater
# Processing Record 8 of Set 2 | blackmans bay
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | port-aux-francais
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | broome
# Processing Record 13 of Set 2 | pak phanang
# Processing Record 14 of Set 2 | djougou
# Processing Record 15 of Set 2 | sidney
# Processing Record 16 of Set 2 | sihanoukville
# Processing Record 17 of Set 2 | dudinka
# Processing Record 18 of Set 2 | yanta
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | tanki leendert
# City not found. Skipping...
# Processing Record 21 of Set 2 | eureka
# Processing Record 22 of Set 2 | labrador city
# Processing Record 23 of Set 2 | margaret river
# Processing Record 24 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 2 | lagoa
# Processing Record 26 of Set 2 | kruisfontein
# Processing Record 27 of Set 2 | cabo san lucas
# Processing Record 28 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | kikwit
# Processing Record 31 of Set 2 | murgab
# Processing Record 32 of Set 2 | the pas
# Processing Record 33 of Set 2 | at taj
# Processing Record 34 of Set 2 | kuraymah
# Processing Record 35 of Set 2 | hotan
# Processing Record 36 of Set 2 | papatowai
# Processing Record 37 of Set 2 | la ronge
# Processing Record 38 of Set 2 | calama
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | pisco
# Processing Record 41 of Set 2 | fale old settlement
# Processing Record 42 of Set 2 | ust-nera
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | touros
# Processing Record 45 of Set 2 | whitehorse
# Processing Record 46 of Set 2 | al 'alamayn
# City not found. Skipping...
# Processing Record 47 of Set 2 | oroqen zizhiqi
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | nishinoomote
# Processing Record 0 of Set 3 | sao paulo de olivenca
# Processing Record 1 of Set 3 | dembi dolo
# Processing Record 2 of Set 3 | walvis bay
# Processing Record 3 of Set 3 | higuera de zaragoza
# Processing Record 4 of Set 3 | xilin hot
# Processing Record 5 of Set 3 | lihue
# Processing Record 6 of Set 3 | tsiombe
# Processing Record 7 of Set 3 | san jose del guaviare
# Processing Record 8 of Set 3 | nova sintra
# Processing Record 9 of Set 3 | keflavik
# Processing Record 10 of Set 3 | pathein
# Processing Record 11 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 12 of Set 3 | cable beach
# City not found. Skipping...
# Processing Record 13 of Set 3 | westport
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | kilindoni
# Processing Record 16 of Set 3 | kyzyl-suu
# Processing Record 17 of Set 3 | bodo
# Processing Record 18 of Set 3 | aasiaat
# Processing Record 19 of Set 3 | college
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | bilibino
# Processing Record 22 of Set 3 | kirakira
# Processing Record 23 of Set 3 | mejit
# Processing Record 24 of Set 3 | san patricio
# Processing Record 25 of Set 3 | st. john's
# Processing Record 26 of Set 3 | murray
# Processing Record 27 of Set 3 | albany
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | tura
# Processing Record 30 of Set 3 | qapqal
# City not found. Skipping...
# Processing Record 31 of Set 3 | cape coast
# Processing Record 32 of Set 3 | tvoroyri
# Processing Record 33 of Set 3 | trenggalek
# Processing Record 34 of Set 3 | nueva gerona
# Processing Record 35 of Set 3 | neiafu
# Processing Record 36 of Set 3 | olonkinbyen
# Processing Record 37 of Set 3 | gurlan
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | anadyr
# Processing Record 40 of Set 3 | kapuskasing
# Processing Record 41 of Set 3 | goure
# Processing Record 42 of Set 3 | nuku'alofa
# Processing Record 43 of Set 3 | afaahiti
# Processing Record 44 of Set 3 | invercargill
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | kyabe
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | atafu village
# Processing Record 49 of Set 3 | mirriah
# Processing Record 0 of Set 4 | constantia
# Processing Record 1 of Set 4 | la'ie
# Processing Record 2 of Set 4 | mansa
# Processing Record 3 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 4 of Set 4 | langfang
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | lompoc
# Processing Record 7 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 8 of Set 4 | dunedin
# Processing Record 9 of Set 4 | tual
# Processing Record 10 of Set 4 | kavaratti
# Processing Record 11 of Set 4 | dongtai
# Processing Record 12 of Set 4 | prum
# Processing Record 13 of Set 4 | pangody
# Processing Record 14 of Set 4 | mount isa
# Processing Record 15 of Set 4 | kapa'a
# Processing Record 16 of Set 4 | udachny
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | tommot
# Processing Record 19 of Set 4 | teknaf
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | qaqortoq
# Processing Record 22 of Set 4 | kalispell
# Processing Record 23 of Set 4 | ugoofaaru
# Processing Record 24 of Set 4 | spittal an der drau
# Processing Record 25 of Set 4 | conception bay south
# Processing Record 26 of Set 4 | acapulco de juarez
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | kerema
# Processing Record 29 of Set 4 | gamay
# Processing Record 30 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 4 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 32 of Set 4 | weno
# Processing Record 33 of Set 4 | hirara
# Processing Record 34 of Set 4 | kokopo
# Processing Record 35 of Set 4 | columbia falls
# Processing Record 36 of Set 4 | rongelap
# Processing Record 37 of Set 4 | cromwell
# Processing Record 38 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 39 of Set 4 | sanya
# Processing Record 40 of Set 4 | oeiras do para
# Processing Record 41 of Set 4 | shimoda
# Processing Record 42 of Set 4 | alice springs
# Processing Record 43 of Set 4 | puerto ayora
# Processing Record 44 of Set 4 | concepcion
# Processing Record 45 of Set 4 | kzyltu
# Processing Record 46 of Set 4 | fujin
# Processing Record 47 of Set 4 | necochea
# Processing Record 48 of Set 4 | gumdag
# Processing Record 49 of Set 4 | inhambane
# Processing Record 0 of Set 5 | cidade velha
# Processing Record 1 of Set 5 | alesund
# Processing Record 2 of Set 5 | brejo
# Processing Record 3 of Set 5 | progreso
# Processing Record 4 of Set 5 | itirucu
# Processing Record 5 of Set 5 | puli
# Processing Record 6 of Set 5 | sitka
# Processing Record 7 of Set 5 | roxas city
# Processing Record 8 of Set 5 | pauini
# Processing Record 9 of Set 5 | furmanov
# Processing Record 10 of Set 5 | klyuchi
# Processing Record 11 of Set 5 | amos
# Processing Record 12 of Set 5 | hadibu
# Processing Record 13 of Set 5 | revda
# Processing Record 14 of Set 5 | monte patria
# Processing Record 15 of Set 5 | islamorada
# Processing Record 16 of Set 5 | novouzensk
# Processing Record 17 of Set 5 | fandrandava
# Processing Record 18 of Set 5 | susuman
# Processing Record 19 of Set 5 | las heras
# Processing Record 20 of Set 5 | okhotsk
# Processing Record 21 of Set 5 | ambon
# Processing Record 22 of Set 5 | murghob
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | vorgashor
# Processing Record 25 of Set 5 | sirte
# Processing Record 26 of Set 5 | mossel bay
# Processing Record 27 of Set 5 | marsh harbour
# Processing Record 28 of Set 5 | dame-marie
# Processing Record 29 of Set 5 | ujae
# Processing Record 30 of Set 5 | tromso
# Processing Record 31 of Set 5 | umba
# Processing Record 32 of Set 5 | pueblo nuevo
# Processing Record 33 of Set 5 | papao
# Processing Record 34 of Set 5 | ruayer
# Processing Record 35 of Set 5 | la romana
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | belyy yar
# Processing Record 38 of Set 5 | hinton
# Processing Record 39 of Set 5 | antalaha
# Processing Record 40 of Set 5 | midvagur
# Processing Record 41 of Set 5 | iskateley
# Processing Record 42 of Set 5 | cole harbour
# Processing Record 43 of Set 5 | ulladulla
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | nguruka
# Processing Record 46 of Set 5 | tanumah
# Processing Record 47 of Set 5 | portland
# Processing Record 48 of Set 5 | port elizabeth
# Processing Record 49 of Set 5 | angaur state
# Processing Record 0 of Set 6 | jatai
# Processing Record 1 of Set 6 | colonia
# Processing Record 2 of Set 6 | palamos
# Processing Record 3 of Set 6 | sinabang
# Processing Record 4 of Set 6 | kingston
# Processing Record 5 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 6 of Set 6 | port saint john's
# Processing Record 7 of Set 6 | mar del plata
# Processing Record 8 of Set 6 | badger
# Processing Record 9 of Set 6 | harstad
# Processing Record 10 of Set 6 | homer
# Processing Record 11 of Set 6 | tomatlan
# Processing Record 12 of Set 6 | tralee
# Processing Record 13 of Set 6 | crane
# Processing Record 14 of Set 6 | vilyuysk
# Processing Record 15 of Set 6 | taksimo
# Processing Record 16 of Set 6 | mount pleasant
# Processing Record 17 of Set 6 | betio village
# Processing Record 18 of Set 6 | ponneri
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | zouerate
# Processing Record 21 of Set 6 | nacozari de garcia
# Processing Record 22 of Set 6 | port douglas
# Processing Record 23 of Set 6 | khovd
# Processing Record 24 of Set 6 | turabah
# Processing Record 25 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | uliastay
# Processing Record 27 of Set 6 | la paz
# Processing Record 28 of Set 6 | ipora
# Processing Record 29 of Set 6 | woodlake
# Processing Record 30 of Set 6 | pointe michel
# Processing Record 31 of Set 6 | enewetak
# Processing Record 32 of Set 6 | nagqu
# Processing Record 33 of Set 6 | vadso
# Processing Record 34 of Set 6 | franceville
# Processing Record 35 of Set 6 | brigantine
# Processing Record 36 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 37 of Set 6 | khorixas
# Processing Record 38 of Set 6 | lembar
# City not found. Skipping...
# Processing Record 39 of Set 6 | eldorado
# Processing Record 40 of Set 6 | faya-largeau
# Processing Record 41 of Set 6 | nafada
# Processing Record 42 of Set 6 | cifuentes
# Processing Record 43 of Set 6 | uturoa
# Processing Record 44 of Set 6 | puerto baquerizo moreno
# Processing Record 45 of Set 6 | praia
# Processing Record 46 of Set 6 | hailar
# Processing Record 47 of Set 6 | chicoral
# City not found. Skipping...
# Processing Record 48 of Set 6 | malanje
# Processing Record 49 of Set 6 | linxia chengguanzhen
# Processing Record 0 of Set 7 | trenton
# Processing Record 1 of Set 7 | minas
# Processing Record 2 of Set 7 | rio de janeiro
# Processing Record 3 of Set 7 | mournies
# Processing Record 4 of Set 7 | kani keli
# Processing Record 5 of Set 7 | rengasdengklok
# Processing Record 6 of Set 7 | new norfolk
# Processing Record 7 of Set 7 | piton saint-leu
# Processing Record 8 of Set 7 | peace river
# Processing Record 9 of Set 7 | el granada
# Processing Record 10 of Set 7 | puerto morazan
# Processing Record 11 of Set 7 | qamdo
# Processing Record 12 of Set 7 | tazacorte
# Processing Record 13 of Set 7 | carambei
# Processing Record 14 of Set 7 | tazovsky
# Processing Record 15 of Set 7 | ninghai
# Processing Record 16 of Set 7 | choyr
# Processing Record 17 of Set 7 | aberdeen
# Processing Record 18 of Set 7 | mili
# Processing Record 19 of Set 7 | anori
# Processing Record 20 of Set 7 | saint-pierre
# Processing Record 21 of Set 7 | horta
# Processing Record 22 of Set 7 | dazhou
# Processing Record 23 of Set 7 | nishifukuma
# Processing Record 24 of Set 7 | hobyo
# Processing Record 25 of Set 7 | stephenville
# Processing Record 26 of Set 7 | clarence town
# Processing Record 27 of Set 7 | coronel du graty
# Processing Record 28 of Set 7 | dzhalagash
# Processing Record 29 of Set 7 | akjoujt
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | wixom
# Processing Record 32 of Set 7 | fort-shevchenko
# Processing Record 33 of Set 7 | borogontsy
# Processing Record 34 of Set 7 | zeya
# Processing Record 35 of Set 7 | roswell
# Processing Record 36 of Set 7 | acarau
# Processing Record 37 of Set 7 | kot samaba
# Processing Record 38 of Set 7 | santa isabel
# Processing Record 39 of Set 7 | illizi
# Processing Record 40 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 41 of Set 7 | huntingdon
# Processing Record 42 of Set 7 | lusambo
# Processing Record 43 of Set 7 | syzran'
# Processing Record 44 of Set 7 | parsons
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | ust'-ilimsk
# Processing Record 47 of Set 7 | severo-yeniseyskiy
# Processing Record 48 of Set 7 | buka
# Processing Record 49 of Set 7 | gizo
# Processing Record 0 of Set 8 | honefoss
# Processing Record 1 of Set 8 | norilsk
# Processing Record 2 of Set 8 | culpeper
# Processing Record 3 of Set 8 | callao
# Processing Record 4 of Set 8 | sake
# Processing Record 5 of Set 8 | whakatane
# Processing Record 6 of Set 8 | pundong
# Processing Record 7 of Set 8 | paramonga
# Processing Record 8 of Set 8 | bel ombre
# Processing Record 9 of Set 8 | mondlo
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | tolanaro
# Processing Record 12 of Set 8 | wagar
# Processing Record 13 of Set 8 | salmas
# Processing Record 14 of Set 8 | shizunai-furukawacho
# Processing Record 15 of Set 8 | altay
# Processing Record 16 of Set 8 | angra dos reis
# Processing Record 17 of Set 8 | as safirah
# Processing Record 18 of Set 8 | shumikha
# Processing Record 19 of Set 8 | wynyard
# Processing Record 20 of Set 8 | pocito
# Processing Record 21 of Set 8 | ust-tsilma
# Processing Record 22 of Set 8 | punta arenas
# Processing Record 23 of Set 8 | brisas de zicatela
# Processing Record 24 of Set 8 | bereznik
# Processing Record 25 of Set 8 | luebo
# Processing Record 26 of Set 8 | birjand
# Processing Record 27 of Set 8 | remire-montjoly
# Processing Record 28 of Set 8 | alagir
# Processing Record 29 of Set 8 | safi
# Processing Record 30 of Set 8 | bengkulu
# Processing Record 31 of Set 8 | al kharijah
# Processing Record 32 of Set 8 | kattivakkam
# Processing Record 33 of Set 8 | tabou
# Processing Record 34 of Set 8 | thinadhoo
# Processing Record 35 of Set 8 | antsohihy
# Processing Record 36 of Set 8 | monrovia
# Processing Record 37 of Set 8 | krasnyy kholm
# Processing Record 38 of Set 8 | askoy
# Processing Record 39 of Set 8 | umaria
# Processing Record 40 of Set 8 | mabaruma
# Processing Record 41 of Set 8 | mahina
# Processing Record 42 of Set 8 | glace bay
# Processing Record 43 of Set 8 | chillicothe
# Processing Record 44 of Set 8 | prince george
# Processing Record 45 of Set 8 | kristiansund
# Processing Record 46 of Set 8 | carbonear
# Processing Record 47 of Set 8 | utena
# Processing Record 48 of Set 8 | am djarass
# City not found. Skipping...
# Processing Record 49 of Set 8 | barmer
# Processing Record 0 of Set 9 | huarmey
# Processing Record 1 of Set 9 | mirnyy
# Processing Record 2 of Set 9 | pilar
# Processing Record 3 of Set 9 | piti village
# Processing Record 4 of Set 9 | arthur's town
# City not found. Skipping...
# Processing Record 5 of Set 9 | adrar
# Processing Record 6 of Set 9 | shalqar
# Processing Record 7 of Set 9 | hithadhoo
# Processing Record 8 of Set 9 | dalandzadgad
# Processing Record 9 of Set 9 | bishkul
# Processing Record 10 of Set 9 | sao felix do xingu
# Processing Record 11 of Set 9 | nar'yan-mar
# Processing Record 12 of Set 9 | tofol
# Processing Record 13 of Set 9 | bol
# Processing Record 14 of Set 9 | itaituba
# Processing Record 15 of Set 9 | palikir - national government center
# Processing Record 16 of Set 9 | springfield
# Processing Record 17 of Set 9 | nizhniy kuranakh
# Processing Record 18 of Set 9 | gojra
# Processing Record 19 of Set 9 | mugia
# Processing Record 20 of Set 9 | alton north (historical)
# Processing Record 21 of Set 9 | borgentreich
# Processing Record 22 of Set 9 | worland
# Processing Record 23 of Set 9 | talovskiy
# Processing Record 24 of Set 9 | yuxia
# Processing Record 25 of Set 9 | abraham's bay
# City not found. Skipping...
# Processing Record 26 of Set 9 | kalemie
# Processing Record 27 of Set 9 | mo i rana
# Processing Record 28 of Set 9 | flying fish cove
# Processing Record 29 of Set 9 | el jem
# Processing Record 30 of Set 9 | holualoa
# Processing Record 31 of Set 9 | chibougamau
# Processing Record 32 of Set 9 | rimouski
# Processing Record 33 of Set 9 | chota
# Processing Record 34 of Set 9 | al burayqah
# Processing Record 35 of Set 9 | aguada de pasajeros
# Processing Record 36 of Set 9 | bargara
# City not found. Skipping...
# Processing Record 37 of Set 9 | xai-xai
# Processing Record 38 of Set 9 | tosontsengel
# Processing Record 39 of Set 9 | haiku-pauwela
# Processing Record 40 of Set 9 | tidjikja
# Processing Record 41 of Set 9 | pekan
# Processing Record 42 of Set 9 | taxisco
# Processing Record 43 of Set 9 | tadine
# Processing Record 44 of Set 9 | magadan
# Processing Record 45 of Set 9 | hami
# Processing Record 46 of Set 9 | kanggye
# Processing Record 47 of Set 9 | rio turbio
# City not found. Skipping...
# Processing Record 48 of Set 9 | puerto lempira
# Processing Record 49 of Set 9 | korla
# Processing Record 0 of Set 10 | lago da pedra
# Processing Record 1 of Set 10 | bondo
# Processing Record 2 of Set 10 | nuuk
# Processing Record 3 of Set 10 | palmas
# Processing Record 4 of Set 10 | linton
# Processing Record 5 of Set 10 | shurugwi
# Processing Record 6 of Set 10 | talodi
# Processing Record 7 of Set 10 | tobol'sk
# Processing Record 8 of Set 10 | damongo
# City not found. Skipping...
# Processing Record 9 of Set 10 | akureyri
# Processing Record 10 of Set 10 | namibe
# Processing Record 11 of Set 10 | arar
# Processing Record 12 of Set 10 | nguigmi
# Processing Record 13 of Set 10 | p'ot'i
# Processing Record 14 of Set 10 | tweed heads
# Processing Record 15 of Set 10 | torghay
# Processing Record 16 of Set 10 | kerikeri
# Processing Record 17 of Set 10 | taroudant
# Processing Record 18 of Set 10 | zaozersk
# Processing Record 19 of Set 10 | perry
# Processing Record 20 of Set 10 | la manga del mar menor
# Processing Record 21 of Set 10 | vila velha
# Processing Record 22 of Set 10 | succasunna
# Processing Record 23 of Set 10 | aykhal
# Processing Record 24 of Set 10 | arecibo
# Processing Record 25 of Set 10 | gornozavodsk
# Processing Record 26 of Set 10 | santa cruz
# Processing Record 27 of Set 10 | berezovyy
# Processing Record 28 of Set 10 | juan griego
# Processing Record 29 of Set 10 | caleta de carquin
# Processing Record 30 of Set 10 | palmer
# Processing Record 31 of Set 10 | babayevo
# Processing Record 32 of Set 10 | tindouf
# Processing Record 33 of Set 10 | barranca
# Processing Record 34 of Set 10 | turpan
# Processing Record 35 of Set 10 | rikaze
# Processing Record 36 of Set 10 | tullamore
# Processing Record 37 of Set 10 | manismata
# Processing Record 38 of Set 10 | belmonte
# Processing Record 39 of Set 10 | slave lake
# Processing Record 40 of Set 10 | howrah
# Processing Record 41 of Set 10 | fort bragg
# Processing Record 42 of Set 10 | freguesia do ribeirao da ilha
# Processing Record 43 of Set 10 | manicore
# Processing Record 44 of Set 10 | aioun
# Processing Record 45 of Set 10 | cromer
# Processing Record 46 of Set 10 | fort st. john
# Processing Record 47 of Set 10 | grevesmuhlen
# Processing Record 48 of Set 10 | beyneu
# Processing Record 49 of Set 10 | modimolle
# Processing Record 0 of Set 11 | voi
# Processing Record 1 of Set 11 | saksaul'skiy
# City not found. Skipping...
# Processing Record 2 of Set 11 | la passe
# Processing Record 3 of Set 11 | raja
# Processing Record 4 of Set 11 | anchorage
# Processing Record 5 of Set 11 | besancon
# Processing Record 6 of Set 11 | quellon
# Processing Record 7 of Set 11 | novo oriente
# Processing Record 8 of Set 11 | almeirim
# Processing Record 9 of Set 11 | metu
# Processing Record 10 of Set 11 | zyryanskoye
# Processing Record 11 of Set 11 | happy valley-goose bay
# Processing Record 12 of Set 11 | igarka
# Processing Record 13 of Set 11 | nantong
# Processing Record 14 of Set 11 | angra do heroismo
# Processing Record 15 of Set 11 | fendou
# Processing Record 16 of Set 11 | mount pearl
# Processing Record 17 of Set 11 | dobrush
# Processing Record 18 of Set 11 | rawai
# Processing Record 19 of Set 11 | kourou
# Processing Record 20 of Set 11 | kolonia town
# Processing Record 21 of Set 11 | puerto francisco de orellana
# Processing Record 22 of Set 11 | saudarkrokur
# Processing Record 23 of Set 11 | zhosaly
# Processing Record 24 of Set 11 | kimbe
# Processing Record 25 of Set 11 | nokha
# Processing Record 26 of Set 11 | machico
# Processing Record 27 of Set 11 | ribeira brava
# Processing Record 28 of Set 11 | sunne
# Processing Record 29 of Set 11 | abu road
# Processing Record 30 of Set 11 | tangalle
# Processing Record 31 of Set 11 | bay minette
# Processing Record 32 of Set 11 | ishigaki
# Processing Record 33 of Set 11 | kailua-kona
# Processing Record 34 of Set 11 | kharovsk
# Processing Record 35 of Set 11 | maun
# Processing Record 36 of Set 11 | asaita
# Processing Record 37 of Set 11 | hiratacho
# Processing Record 38 of Set 11 | puerto deseado
# Processing Record 39 of Set 11 | harnosand
# Processing Record 40 of Set 11 | urucara
# Processing Record 41 of Set 11 | sur
# Processing Record 42 of Set 11 | selfoss
# Processing Record 43 of Set 11 | egilsstadir
# Processing Record 44 of Set 11 | nemuro
# Processing Record 45 of Set 11 | port alberni
# Processing Record 46 of Set 11 | plesetsk
# Processing Record 47 of Set 11 | tshabong
# Processing Record 48 of Set 11 | broken hill
# Processing Record 49 of Set 11 | basco
# Processing Record 0 of Set 12 | batouri
# Processing Record 1 of Set 12 | alik ghund
# Processing Record 2 of Set 12 | verkh-chebula
# Processing Record 3 of Set 12 | springbok
# Processing Record 4 of Set 12 | carrigaline
# Processing Record 5 of Set 12 | lazaro cardenas
# Processing Record 6 of Set 12 | plouzane
# Processing Record 7 of Set 12 | nelson bay
# Processing Record 8 of Set 12 | jobner
# Processing Record 9 of Set 12 | siwa oasis
# Processing Record 10 of Set 12 | galliano
# Processing Record 11 of Set 12 | muriti
# Processing Record 12 of Set 12 | santa maria del rio
# Processing Record 13 of Set 12 | bahia de caraquez
# Processing Record 14 of Set 12 | opuwo
# Processing Record 15 of Set 12 | vilyuchinsk
# Processing Record 16 of Set 12 | adigrat
# Processing Record 17 of Set 12 | kodok
# City not found. Skipping...
# Processing Record 18 of Set 12 | dover
# Processing Record 19 of Set 12 | hilo
# Processing Record 20 of Set 12 | ust'-kut
# Processing Record 21 of Set 12 | nikolayevsk-on-amure
# Processing Record 22 of Set 12 | vorkuta
# Processing Record 23 of Set 12 | fayzabad
# Processing Record 24 of Set 12 | bonthe
# Processing Record 25 of Set 12 | chiredzi
# Processing Record 26 of Set 12 | san jeronimo de juarez
# Processing Record 27 of Set 12 | talara
# Processing Record 28 of Set 12 | kachug
# Processing Record 29 of Set 12 | morondava
# Processing Record 30 of Set 12 | borkum
# Processing Record 31 of Set 12 | inda silase
# Processing Record 32 of Set 12 | houghton
# Processing Record 33 of Set 12 | beihai
# Processing Record 34 of Set 12 | ulsteinvik
# Processing Record 35 of Set 12 | ji'an
# Processing Record 36 of Set 12 | itoman
# Processing Record 37 of Set 12 | dawei
# Processing Record 38 of Set 12 | nsanje
# Processing Record 39 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 40 of Set 12 | sumbe
# Processing Record 41 of Set 12 | dondo
# Processing Record 42 of Set 12 | sinop
# Processing Record 43 of Set 12 | mittagong
# Processing Record 44 of Set 12 | krasnoturansk
# Processing Record 45 of Set 12 | covington
# Processing Record 46 of Set 12 | camana
# Processing Record 47 of Set 12 | rio preto da eva
# Processing Record 48 of Set 12 | mthatha
# Processing Record 49 of Set 12 | panitian
# Processing Record 0 of Set 13 | upington
# Processing Record 1 of Set 13 | pineda de mar
# Processing Record 2 of Set 13 | jieshi
# Processing Record 3 of Set 13 | kolonia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            abepura  -2.6333  140.5833     32.45        58          20
# 1   katsuren-haebaru  26.3369  127.8719     25.05        60          20
# 2              utrik  11.2278  169.8474     26.96        84           8
# 3  wailua homesteads  22.0669 -159.3780     23.24        85         100
# 4          grytviken -54.2811  -36.5092      4.24        98         100
#
#    Wind Speed Country        Date
# 0        1.54      ID  1713492651
# 1        5.66      JP  1713492653
# 2       10.32      MH  1713492654
# 3        7.72      US  1713492655
# 4        0.74      GS  1713492656

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  abepura  -2.6333  140.5833     32.45        58          20
# 1         katsuren-haebaru  26.3369  127.8719     25.05        60          20
# 2                    utrik  11.2278  169.8474     26.96        84           8
# 3        wailua homesteads  22.0669 -159.3780     23.24        85         100
# 4                grytviken -54.2811  -36.5092      4.24        98         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      ID  1713492651
# 1              5.66      JP  1713492653
# 2             10.32      MH  1713492654
# 3              7.72      US  1713492655
# 4              0.74      GS  1713492656

# %%
# Build scatter plot for latitude vs. Max temperature:
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='black')


# Incorporate the other graph properties:

# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Max Temperature (°C)')

# Title the scatter plot:
    # Scatter plot has the date of the data collection, 
    # must collect the first date in the dataframe.
timestamp = city_data_df.loc[0, 'Date']
    # Format from the dataframe format into a readable format.
date = datetime.utcfromtimestamp(timestamp)
    # Match the format to the required output.
formatted_date = date.strftime('%d/%m/%Y')

# Title the scatter plot.
plt.title(f'City Latitude vs Max Temperature ({formatted_date})')
# Put a grid onto the scatter plot.
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity:
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='black')


# Incorporate the other graph properties:

# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Humidity (%)')

# Title the scatter plot:
    # Scatter plot has the date of the data collection, 
    # must collect the first date in the dataframe.
timestamp = city_data_df.loc[0, 'Date']
    # Format from the dataframe format into a readable format.
date = datetime.utcfromtimestamp(timestamp)
    # Match the format to the required output.
formatted_date = date.strftime('%d/%m/%Y')

# Title the scatter plot.
plt.title(f'City Latitude vs Humidity ({formatted_date})')
# Put a grid onto the scatter plot.
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. Cloudiness:
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='black')


# Incorporate the other graph properties:

# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Cloudiness (%)')

# Title the scatter plot:
    # Scatter plot has the date of the data collection, 
    # must collect the first date in the dataframe.
timestamp = city_data_df.loc[0, 'Date']
    # Format from the dataframe format into a readable format.
date = datetime.utcfromtimestamp(timestamp)
    # Match the format to the required output.
formatted_date = date.strftime('%d/%m/%Y')

# Title the scatter plot.
plt.title(f'City Latitude vs Cloudiness ({formatted_date})')
# Put a grid onto the scatter plot.
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. Wind Speed:
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='black')


# Incorporate the other graph properties:

# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Wind Speed (m/s)')

# Title the scatter plot:
    # Scatter plot has the date of the data collection, 
    # must collect the first date in the dataframe.
timestamp = city_data_df.loc[0, 'Date']
    # Format from the dataframe format into a readable format.
date = datetime.utcfromtimestamp(timestamp)
    # Match the format to the required output.
formatted_date = date.strftime('%d/%m/%Y')

# Title the scatter plot.
plt.title(f'City Latitude vs Wind Speed ({formatted_date})')
# Put a grid onto the scatter plot.
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Define a function to create Linear Regression plots
def Linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    regress_values = slope * x_values + intercept
    line_eq = "y = " + str(round(slope, 2)) + "*x + " + str(round(intercept, 2))
    
    return x_values, line_eq, regress_values, rvalue

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         katsuren-haebaru  26.3369  127.8719     25.05        60          20
# 2                    utrik  11.2278  169.8474     26.96        84           8
# 3        wailua homesteads  22.0669 -159.3780     23.24        85         100
# 5             longyearbyen  78.2186   15.6401     -1.09        59          75
# 7                   lisala   2.1500   21.5167     21.69        98         100
#
#          Wind Speed Country        Date
# City_ID
# 1              5.66      JP  1713492653
# 2             10.32      MH  1713492654
# 3              7.72      US  1713492655
# 5              7.20      SJ  1713492607
# 7              1.39      CD  1713492659

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            abepura  -2.6333  140.5833     32.45        58          20
# 4          grytviken -54.2811  -36.5092      4.24        98         100
# 6        west island -12.1568   96.8225     28.99        70          40
# 8           waitangi -43.9535 -176.5597     17.12        84         100
# 9               ta`u -14.2336 -169.5144     29.22        76          15
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      ID  1713492651
# 4              0.74      GS  1713492656
# 6              5.14      CC  1713492658
# 8              2.24      NZ  1713492518
# 9              6.22      AS  1713492662

# %%
# Linear regression on Northern Hemisphere Max Temp Vs. Latitude:

# Build scatter plot for latitude vs. Max temperature:
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

x_values, line_eq, regress_values, rvalue = Linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Max Temperature')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.1, 0.25), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7744670506318632

# %%
# Linear regression on southern Hemisphere Max Temp Vs. Latitude:

# Build scatter plot for latitude vs. Max temperature:
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])

x_values, line_eq, regress_values, rvalue = Linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Max Temperature')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.05, 0.85), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Print Discussion of the linear relationship Cloudiness Vs Latitude.
print("\033[1m Discussion about the linear relationship:\033[0m")
print(" MY DISCUSSION ABOUT LINEAR RELATIONSHIP Max Temperature Vs Latitude")
# Out:
# The r-value is: 0.5032476800658201
#  Discussion about the linear relationship:
#  MY DISCUSSION ABOUT LINEAR RELATIONSHIP Max Temperature Vs Latitude

# %%
# Linear regression on Northern Hemisphere Humidity Vs. Latitude:

# Build scatter plot for latitude vs. Humidity:
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

x_values, line_eq, regress_values, rvalue = Linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Humidity')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.5, 0.05), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.03618233287124113

# %%
# Linear regression on southern Hemisphere Humidity Vs. Latitude:

# Build scatter plot for latitude vs. Humidity:
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

x_values, line_eq, regress_values, rvalue = Linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Humidity')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.1, 0.1), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Print Discussion of the linear relationship Humidity Vs Latitude.
print("\033[1m Discussion about the linear relationship:\033[0m")
print(" MY DISCUSSION ABOUT LINEAR RELATIONSHIP Humidity Vs Latitude")
# Out:
# The r-value is: 0.0912023948104603
#  Discussion about the linear relationship:
#  MY DISCUSSION ABOUT LINEAR RELATIONSHIP Humidity Vs Latitude

# %%
# Linear regression on Northern Hemisphere Cloudiness Vs. Latitude:

# Build scatter plot for latitude vs. Cloudiness:
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

x_values, line_eq, regress_values, rvalue = Linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Cloudiness')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.5, 0.14), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.02041882015249405

# %%
# Linear regression on southern Hemisphere Cloudiness Vs. Latitude:

# Build scatter plot for latitude vs. Cloudiness:
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

x_values, line_eq, regress_values, rvalue = Linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Cloudiness')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.4, 0.35), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Print Discussion of the linear relationship Cloudiness Vs Latitude.
print("\033[1m Discussion about the linear relationship:\033[0m")
print(" MY DISCUSSION ABOUT LINEAR RELATIONSHIP Cloudiness Vs Latitude")
# Out:
# The r-value is: 0.0074776640556715535

# %%
# Linear regression on Northern Wind Speed Vs. Latitude:

# Build scatter plot for latitude vs. Wind Speed:
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

x_values, line_eq, regress_values, rvalue = Linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Wind Speed')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.15, 0.8), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.002288196399034442

# %%
# Linear regression on southern Hemisphere Wind Speed Vs. Latitude:

# Build scatter plot for latitude vs. Wind Speed:
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

x_values, line_eq, regress_values, rvalue = Linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

# Incorporate the other graph properties:
# Label The X-Axis
plt.xlabel('Latitude')
# Label The Y-Axis
plt.ylabel('Wind Speed')

# ANNOTATE the graph with the linear equation relative to the size of the graph.
plt.annotate(line_eq, (0.15, 0.8), xycoords='axes fraction', fontsize = 15, color = 'red')
plt.plot(x_values, regress_values, 'r-')

# Print the r-value.
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Print Discussion of the linear relationship Wind Speed Vs Latitude.
print("\033[1m Discussion about the linear relationship:\033[0m")
print(" MY DISCUSSION ABOUT LINEAR RELATIONSHIP BLAH BLAH BLAH")
# Out:
# The r-value is: 0.12053235897825548
#  Discussion about the linear relationship:
#  MY DISCUSSION ABOUT LINEAR RELATIONSHIP BLAH BLAH BLAH
